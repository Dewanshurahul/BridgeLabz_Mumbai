# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import plotly.express as px

# %%
x = np.random.randint(50,size=1000)
y = np.random.randint(50,size=1000)
df = pd.DataFrame({'x': x,'y': y})
df.head(7)
# Out:
#     x   y
# 0   7   8
# 1  13  25
# 2  20  18
# 3  17  47
# 4  49  12
# 5  30  42
# 6  36  28

# %%
px.bar(df,df['x'],df['y'],color='x')
# Out:
# <div>
#
#
#             <div id="229ae642-2716-4a80-882d-f08d8d6cd0c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("229ae642-2716-4a80-882d-f08d8d6cd0c8")) {
#                     Plotly.newPlot(
#                         '229ae642-2716-4a80-882d-f08d8d6cd0c8',
# ...
