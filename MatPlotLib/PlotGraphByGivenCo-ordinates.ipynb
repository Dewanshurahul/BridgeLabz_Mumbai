# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('test.txt',sep=" ", header = None)
dataArray = np.array(data)
dataArray
# Out:
# array([[1, 2],
#        [2, 4],
#        [3, 1]])

# %%
x = dataArray[:,0]
y = dataArray[:,1]

# %%
plt.plot(x,y)
