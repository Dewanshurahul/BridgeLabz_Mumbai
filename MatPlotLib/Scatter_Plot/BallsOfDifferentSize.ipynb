# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
x = np.random.randint(10,size=70)
y = np.random.randint(10,size=70)

# %%
df = pd.DataFrame({'x': x,'y': y})

# %%
colors = np.random.randint(1,4,70)
colors
plt.scatter(df['x'],df['y'],s=np.random.randint(100,size=70),c=colors)
plt.show()
