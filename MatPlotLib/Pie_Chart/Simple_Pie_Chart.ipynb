# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {'Programming_languages': ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'],
'Popularity': [22.2, 17.6, 8.8, 8, 7.7, 6.7]
}
df = pd.DataFrame(data)
df
# Out:
#   Programming_languages  Popularity
# 0                  Java        22.2
# 1                Python        17.6
# 2                   PHP         8.8
# 3            JavaScript         8.0
# 4                    C#         7.7
# 5                   C++         6.7

# %%
plt.pie(df['Popularity'],labels=df['Programming_languages'],shadow=True,labeldistance=0.7,radius=3)
plt.show()
