# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(100)
y = x ** 3

# %%
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('First Graph')
# Out:
# Text(0.5, 1.0, 'First Graph')
